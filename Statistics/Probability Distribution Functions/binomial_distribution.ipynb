# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# n = the no.of trails 
# size = total no.of experiment

n = 10
p = 0.5
size = 1000



binomial_dist = np.random.binomial(n,p,size)

plt.hist(binomial_dist,density=True)
plt.show()
